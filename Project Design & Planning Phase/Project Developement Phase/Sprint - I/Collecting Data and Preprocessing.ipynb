# %% [markdown]
# Sprint 1

# %% [markdown]
# Team Id:PNT2022TMID25747

# %% [markdown]
# Libraries

# %%
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
import keras

# %% [markdown]
# Preprocess the Data

# %%
from keras.datasets import mnist

(X_train,X_test),(Y_train,Y_test)=mnist.load_data()
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %% [markdown]
# View MNIST images

# %%
def plot_input_img(i):
    plt.imshow(X_train[i],cmap='binary')
    plt.title(Y_train[i])
    plt.axes('off')
    plt.show()

for i in range(10):
    plot_input_img(i)
# Out:
# C:\Users\hari9\anaconda3\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28796\2854886630.py in <module>
#       6
#       7 for i in range(10):
# ----> 8     plot_input_img(i)
#
# ~\AppData\Local\Temp\ipykernel_28796\2854886630.py in plot_input_img(i)
#       2     plt.imshow(X_train[i],cmap='binary')
#       3     plt.title(Y_train[i])
# ----> 4     plt.axes('off')
#       5     plt.show()
#       6
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in axes(arg, **kwargs)
#    1088             return fig.add_axes(pos, **kwargs)
#    1089     else:
# -> 1090         return fig.add_axes(arg, **kwargs)
#    1091
#    1092
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_axes(self, *args, **kwargs)
#     633         else:
#     634             rect = args[0]
# --> 635             if not np.isfinite(rect).all():
#     636                 raise ValueError('all entries in rect must be finite '
#     637                                  'not {}'.format(rect))
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# Preprocess the Images

# %% [markdown]
# Normalizing the Images

# %%
X_train=X_train.astype(np.float_32)/255
X_test=X_test.astype(np.float_32)/255

#Reshaping the Image
X_train=np.expand_dims(X_train,-1)
X_test=np.expand_dims(X_test,-1)

# %% [markdown]
# One Hot Encoding

# %%
Y_train=keras.utils.to_categorical(Y_train)
Y_test=keras.utils.to_categorical(Y_test)
